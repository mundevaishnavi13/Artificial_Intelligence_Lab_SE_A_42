# %% [markdown]
# <a href="https://colab.research.google.com/github/mundevaishnavi13/Artificial_Intelligence_Lab_SE_A_42/blob/master/table_of_num.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check if a number is a palindrome
def is_palindrome(number):
    # Convert number to string to easily reverse it
    num_str = str(number)
    reversed_num_str = num_str[::-1]

    if num_str == reversed_num_str:
        print(f"The number {number} is a palindrome.")
    else:
        print(f"The number {number} is not a palindrome.")

# Ask the user to enter a number
try:
    num_to_check = int(input("Enter a number to check if it's a palindrome: "))
    is_palindrome(num_to_check)
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to check if it's a palindrome: 5
# The number 5 is a palindrome.

# %%
 check num is odd or even

# %%
# Function to check if a number is odd or even
def check_odd_even(number):
    if number % 2 == 0:
        print(f"The number {number} is even.")
    else:
        print(f"The number {number} is odd.")

# Ask the user to enter a number
try:
    num_to_check = int(input("Enter a number to check if it's odd or even: "))
    check_odd_even(num_to_check)
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to check if it's odd or even: 10
# The number 10 is even.

# %%
table of number

# %%
# Function to display the multiplication table
def display_multiplication_table(number):
    print(f"Multiplication Table for {number}:")
    for i in range(1, 11): # Table from 1 to 10
        print(f"{number} x {i} = {number * i}")

# Ask the user to enter a number
try:
    num_for_table = int(input("Enter a number to display its multiplication table: "))
    display_multiplication_table(num_for_table)
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to display its multiplication table: 7
# Multiplication Table for 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
print("hello google colab")
# Out:
# hello google colab

# %% [markdown]
# factorial of given number

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

# Ask the user to enter a number
try:
    num = int(input("Enter a non-negative integer: "))
    result = factorial(num)
    print(f"The factorial of {num} is: {result}")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a non-negative integer: 5
# The factorial of 5 is: 120

# %%
# Get user input for mood
mood = input("How are you feeling today? (e.g., happy, sad, bored): ").lower().strip()

# Apply simple IF-ELSE rules for decision-making
if "happy" in mood:
    print("Great! Maybe go for a walk in the park.")
elif "sad" in mood:
    print("I'm sorry to hear that. How about listening to some uplifting music?")
elif "bored" in mood:
    print("Let's find something fun! Try reading a book or learning a new skill online.")
else:
    print("I'm not sure how to respond to that feeling. Try expressing it differently.")
# Out:
# How are you feeling today? (e.g., happy, sad, bored): happy
# Great! Maybe go for a walk in the park.
